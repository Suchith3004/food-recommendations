# %%
import pandas as pd
import gzip
import json

# %%
def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield json.loads(l)

def getDf(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %%
df = getDf('./Grocery_and_Gourmet_Food_5.json.gz')

# %%
df_cleaned = df.drop(columns=['reviewTime', 'unixReviewTime', 'style', 'image'])

# %%
df_cleaned = df_cleaned[df_cleaned['verified'] == True]

# %%
df_cleaned = df_cleaned.drop(columns='verified')

# %%
to_csv = df_cleaned.to_csv('./gourmet_foods.csv', index=False)

# %%
df_cleaned
# Out:
#          overall      reviewerID        asin     reviewerName  \
# 0            5.0  A1QVBUH9E1V6I8  4639725183   Jamshed Mathur
# 1            5.0  A3GEOILWLK86XM  4639725183        itsjustme
# 2            5.0  A32RD6L701BIGP  4639725183  Krystal Clifton
# 3            5.0  A2UY1O1FBGKIE6  4639725183          U. Kane
# 4            5.0  A3QHVBQYDV7Z6U  4639725183         The Nana
# ...          ...             ...         ...              ...
# 1143855      5.0  A223YRQH2Z5T1D  B01HJF6FRA        flint5292
# 1143856      5.0  A38GDA4TB9EILT  B01HJF6FRA   Moriah Bolyard
# 1143857      5.0  A2025PN7HDC5BO  B01HJF6FRA              M.C
# 1143858      5.0  A1NY7XWC7EPQOA  B01HJF6FRA       Greensboro
# 1143859      3.0  A1P0X9E6F99J4T  B01HJF6FRA          Qoyllor
#
#                                                 reviewText  \
# 0                                      No adverse comment.
# 1                                Gift for college student.
# ...
